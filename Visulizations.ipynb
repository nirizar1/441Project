# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
df = pd.read_csv('insertion_sort_results.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2
# 0      6103.0     34290.0    0.034290
# 1         NaN         NaN         NaN
# 2      3162.0      8644.0    0.008644
# 3         NaN         NaN         NaN
# 4     11724.0    119567.0    0.119567
# 5         NaN         NaN         NaN
# 6      9376.0     79102.0    0.079102
# 7         NaN         NaN         NaN
# 8      8714.0     66322.0    0.066322
# 9         NaN         NaN         NaN

# %%
df = df.rename(columns={'Unnamed: 0' :'Size','Unnamed: 1':'Ticks', 'Unnamed: 2': 'Seconds' })

# %%
df.dropna()
# Out:
#          Size     Ticks   Seconds
# 0      6103.0   34290.0  0.034290
# 2      3162.0    8644.0  0.008644
# 4     11724.0  119567.0  0.119567
# 6      9376.0   79102.0  0.079102
# 8      8714.0   66322.0  0.066322
# ...       ...       ...       ...
# 1990   3769.0   12464.0  0.012464
# 1992  11904.0  129145.0  0.129145
# 1994  10639.0  103806.0  0.103806
# 1996  12607.0  151761.0  0.151761
# 1998  11486.0  135545.0  0.135545
#
# [1000 rows x 3 columns]

# %%
plt.scatter(df['Size'], df['Seconds'])
plt.xlabel('Array Size')
plt.ylabel('Sort Time in Seconds')
plt.title('Insertion Sort Time in Seconds')
plt.show()

# %%
df = pd.read_csv('quick_sort_results.csv')
df = df.rename(columns={'Unnamed: 0' :'Size','Unnamed: 1':'Ticks', 'Unnamed: 2': 'Seconds' })
df.dropna()
# Out:
#          Size   Ticks   Seconds
# 0      9341.0  1484.0  0.001484
# 2      4455.0   684.0  0.000684
# 4     10114.0  1531.0  0.001531
# 6      4906.0   693.0  0.000693
# 8     10871.0  1575.0  0.001575
# ...       ...     ...       ...
# 1990   5835.0   817.0  0.000817
# 1992   9520.0  1549.0  0.001549
# 1994   3439.0   504.0  0.000504
# 1996  11055.0  1864.0  0.001864
# 1998   4096.0   562.0  0.000562
#
# [1000 rows x 3 columns]

# %%
plt.scatter(df['Size'], df['Seconds'])
plt.xlabel('Array Size')
plt.ylabel('Sort Time in Seconds')
plt.title('Quick Sort Time in Seconds')
plt.show()
